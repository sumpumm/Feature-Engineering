# %% [markdown]
# <a href="https://colab.research.google.com/github/sumpumm/Feature-Engineering/blob/main/Pipelines/predict_without_Pipelines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('/content/drive/MyDrive/Machine Learning from scratch/Feature Engineering-04/Scikit Learn Pipelines/models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('/content/drive/MyDrive/Machine Learning from scratch/Feature Engineering-04/Scikit Learn Pipelines/models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('/content/drive/MyDrive/Machine Learning from scratch/Feature Engineering-04/Scikit Learn Pipelines/models/clf.pkl','rb'))

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input.ndim
# Out:
# 2

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input[:,1]
# Out:
# array(['male'], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
clf.predict(test_input_transformed)
# Out:
# array([0])
